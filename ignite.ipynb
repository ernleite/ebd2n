# %%
# %pip install ignite
# Out:
# Requirement already satisfied: ignite in /home/aiuser/miniconda/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: requests in /home/aiuser/miniconda/lib/python3.11/site-packages (from ignite) (2.31.0)
# Requirement already satisfied: wrapt in /home/aiuser/miniconda/lib/python3.11/site-packages (from ignite) (1.17.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/aiuser/miniconda/lib/python3.11/site-packages (from requests->ignite) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/aiuser/miniconda/lib/python3.11/site-packages (from requests->ignite) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/aiuser/miniconda/lib/python3.11/site-packages (from requests->ignite) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/aiuser/miniconda/lib/python3.11/site-packages (from requests->ignite) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pytorch-ignite
# Out:
# Requirement already satisfied: pytorch-ignite in /home/aiuser/miniconda/lib/python3.11/site-packages (0.5.2)
# Requirement already satisfied: torch<3,>=1.3 in /home/aiuser/miniconda/lib/python3.11/site-packages (from pytorch-ignite) (2.3.1)
# Requirement already satisfied: packaging in /home/aiuser/miniconda/lib/python3.11/site-packages (from pytorch-ignite) (23.1)
# Requirement already satisfied: filelock in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (4.12.2)
# Requirement already satisfied: sympy in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (1.13.1)
# Requirement already satisfied: networkx in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (3.3)
# Requirement already satisfied: jinja2 in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (3.1.4)
# Requirement already satisfied: fsspec in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /home/aiuser/miniconda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/aiuser/miniconda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<3,>=1.3->pytorch-ignite) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/aiuser/miniconda/lib/python3.11/site-packages (from jinja2->torch<3,>=1.3->pytorch-ignite) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/aiuser/miniconda/lib/python3.11/site-packages (from sympy->torch<3,>=1.3->pytorch-ignite) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision.models import resnet18
from torchvision.transforms import Compose, Normalize, ToTensor

from ignite.engine import Engine, EventEnum, Events, create_supervised_evaluator
from ignite.metrics import Accuracy, Loss
from ignite.handlers import Timer
from ignite.contrib.handlers import BasicTimeProfiler, HandlersTimeProfiler

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        self.model = resnet18(num_classes=10)
        self.model.conv1 = nn.Conv2d(1, 64, kernel_size=3, padding=1, bias=False)

    def forward(self, x):
        return self.model(x)


model = Net().to(device)

data_transform = Compose([ToTensor(), Normalize((0.1307,), (0.3081,))])

train_loader = DataLoader(
    MNIST(download=True, root=".", transform=data_transform, train=True),
    batch_size=128,
    shuffle=True,
)

optimizer = torch.optim.RMSprop(model.parameters(), lr=0.005)
criterion = nn.CrossEntropyLoss()

# %%
class BackpropEvents(EventEnum):
    BACKWARD_STARTED = 'backward_started'
    BACKWARD_COMPLETED = 'backward_completed'
    OPTIM_STEP_COMPLETED = 'optim_step_completed'

# %%
def train_step(engine, batch):
    model.train()
    optimizer.zero_grad()
    x, y = batch[0].to(device), batch[1].to(device)
    y_pred = model(x)
    loss = criterion(y_pred, y)
    
    engine.fire_event(BackpropEvents.BACKWARD_STARTED)
    loss.backward()
    engine.fire_event(BackpropEvents.BACKWARD_COMPLETED)

    optimizer.step()
    engine.fire_event(BackpropEvents.OPTIM_STEP_COMPLETED)

    return loss.item()


trainer = Engine(train_step)

# %%
trainer.register_events(*BackpropEvents)

# %%
@trainer.on(BackpropEvents.BACKWARD_COMPLETED)
def function_before_backprop(engine):
    print(f"Iter[{engine.state.iteration}] Function fired after backward pass")

# %%
trainer.run(train_loader, max_epochs=3)
# Out:
# Iter[1] Function fired after backward pass
# Iter[2] Function fired after backward pass
# Iter[3] Function fired after backward pass
# Iter[4] Function fired after backward pass
# Iter[5] Function fired after backward pass
# Iter[6] Function fired after backward pass
# Iter[7] Function fired after backward pass
# Iter[8] Function fired after backward pass
# Iter[9] Function fired after backward pass
# Iter[10] Function fired after backward pass
# Iter[11] Function fired after backward pass
# Iter[12] Function fired after backward pass
# Iter[13] Function fired after backward pass
# Iter[14] Function fired after backward pass
# Iter[15] Function fired after backward pass
# Iter[16] Function fired after backward pass
# Iter[17] Function fired after backward pass
# Iter[18] Function fired after backward pass
# Iter[19] Function fired after backward pass
# Iter[20] Function fired after backward pass
# Iter[21] Function fired after backward pass
# Iter[22] Function fired after backward pass
# Iter[23] Function fired after backward pass
# Iter[24] Function fired after backward pass
# Iter[25] Function fired after backward pass
# Iter[26] Function fired after backward pass
# Iter[27] Function fired after backward pass
# Iter[28] Function fired after backward pass
# Iter[29] Function fired after backward pass
# Iter[30] Function fired after backward pass
# Iter[31] Function fired after backward pass
# Iter[32] Function fired after backward pass
# Iter[33] Function fired after backward pass
# Iter[34] Function fired after backward pass
# Iter[35] Function fired after backward pass
# Iter[36] Function fired after backward pass
# Iter[37] Function fired after backward pass
# Iter[38] Function fired after backward pass
# Iter[39] Function fired after backward pass
# Iter[40] Function fired after backward pass
# Iter[41] Function fired after backward pass
# Iter[42] Function fired after backward pass
# Iter[43] Function fired after backward pass
# Iter[44] Function fired after backward pass
# Iter[45] Function fired after backward pass
# Iter[46] Function fired after backward pass
# Iter[47] Function fired after backward pass
# Iter[48] Function fired after backward pass
# Iter[49] Function fired after backward pass
# Iter[50] Function fired after backward pass
# Iter[51] Function fired after backward pass
# Iter[52] Function fired after backward pass
# Iter[53] Function fired after backward pass
# Iter[54] Function fired after backward pass
# Iter[55] Function fired after backward pass
# Iter[56] Function fired after backward pass
# Iter[57] Function fired after backward pass
# Iter[58] Function fired after backward pass
# Iter[59] Function fired after backward pass
# Iter[60] Function fired after backward pass
# Iter[61] Function fired after backward pass
# Iter[62] Function fired after backward pass
# Iter[63] Function fired after backward pass
# Iter[64] Function fired after backward pass
# Iter[65] Function fired after backward pass
# Iter[66] Function fired after backward pass
# Iter[67] Function fired after backward pass
# Iter[68] Function fired after backward pass
# Iter[69] Function fired after backward pass
# Iter[70] Function fired after backward pass
# Iter[71] Function fired after backward pass
# Iter[72] Function fired after backward pass
# Iter[73] Function fired after backward pass
# Iter[74] Function fired after backward pass
# Iter[75] Function fired after backward pass
# Iter[76] Function fired after backward pass
# Iter[77] Function fired after backward pass
# Iter[78] Function fired after backward pass
# Iter[79] Function fired after backward pass
# Iter[80] Function fired after backward pass
# Iter[81] Function fired after backward pass
# Iter[82] Function fired after backward pass
# Iter[83] Function fired after backward pass
# Iter[84] Function fired after backward pass
# Iter[85] Function fired after backward pass
# Iter[86] Function fired after backward pass
# Iter[87] Function fired after backward pass
# Iter[88] Function fired after backward pass
# Iter[89] Function fired after backward pass
# Iter[90] Function fired after backward pass
# Iter[91] Function fired after backward pass
# Iter[92] Function fired after backward pass
# Iter[93] Function fired after backward pass
# Iter[94] Function fired after backward pass
# Iter[95] Function fired after backward pass
# Iter[96] Function fired after backward pass
# Iter[97] Function fired after backward pass
# Iter[98] Function fired after backward pass
# Iter[99] Function fired after backward pass
# Iter[100] Function fired after backward pass
# Iter[101] Function fired after backward pass
# Iter[102] Function fired after backward pass
# Iter[103] Function fired after backward pass
# Iter[104] Function fired after backward pass
# Iter[105] Function fired after backward pass
# Iter[106] Function fired after backward pass
# Iter[107] Function fired after backward pass
# Iter[108] Function fired after backward pass
# Iter[109] Function fired after backward pass
# Iter[110] Function fired after backward pass
# Iter[111] Function fired after backward pass
# Iter[112] Function fired after backward pass
# Iter[113] Function fired after backward pass
# Iter[114] Function fired after backward pass
# Iter[115] Function fired after backward pass
# Iter[116] Function fired after backward pass
# Iter[117] Function fired after backward pass
# Iter[118] Function fired after backward pass
# Iter[119] Function fired after backward pass
# Iter[120] Function fired after backward pass
# Iter[121] Function fired after backward pass
# Iter[122] Function fired after backward pass
# Iter[123] Function fired after backward pass
# Iter[124] Function fired after backward pass
# Iter[125] Function fired after backward pass
# Iter[126] Function fired after backward pass
# Iter[127] Function fired after backward pass
# Iter[128] Function fired after backward pass
# Iter[129] Function fired after backward pass
# Iter[130] Function fired after backward pass
# Iter[131] Function fired after backward pass
# Iter[132] Function fired after backward pass
# Iter[133] Function fired after backward pass
# Iter[134] Function fired after backward pass
# Iter[135] Function fired after backward pass
# Iter[136] Function fired after backward pass
# Iter[137] Function fired after backward pass
# Iter[138] Function fired after backward pass
# Iter[139] Function fired after backward pass
# Iter[140] Function fired after backward pass
# Iter[141] Function fired after backward pass
# Iter[142] Function fired after backward pass
# Iter[143] Function fired after backward pass
# Iter[144] Function fired after backward pass
# Iter[145] Function fired after backward pass
# Iter[146] Function fired after backward pass
# Iter[147] Function fired after backward pass
# Iter[148] Function fired after backward pass
# Iter[149] Function fired after backward pass
# Iter[150] Function fired after backward pass
# Iter[151] Function fired after backward pass
# Iter[152] Function fired after backward pass
# Iter[153] Function fired after backward pass
# Iter[154] Function fired after backward pass
# Iter[155] Function fired after backward pass
# Iter[156] Function fired after backward pass
# Iter[157] Function fired after backward pass
# Iter[158] Function fired after backward pass
# Iter[159] Function fired after backward pass
# Iter[160] Function fired after backward pass
# Iter[161] Function fired after backward pass
# Iter[162] Function fired after backward pass
# Iter[163] Function fired after backward pass
# Iter[164] Function fired after backward pass
# Iter[165] Function fired after backward pass
# Iter[166] Function fired after backward pass
# Iter[167] Function fired after backward pass
# Iter[168] Function fired after backward pass
# Iter[169] Function fired after backward pass
# Iter[170] Function fired after backward pass
# Iter[171] Function fired after backward pass
# Iter[172] Function fired after backward pass
# Iter[173] Function fired after backward pass
# Iter[174] Function fired after backward pass
# Iter[175] Function fired after backward pass
# Iter[176] Function fired after backward pass
# Iter[177] Function fired after backward pass
# Iter[178] Function fired after backward pass
# Iter[179] Function fired after backward pass
# Iter[180] Function fired after backward pass
# Iter[181] Function fired after backward pass
# Iter[182] Function fired after backward pass
# Iter[183] Function fired after backward pass
# Iter[184] Function fired after backward pass
# Iter[185] Function fired after backward pass
# Iter[186] Function fired after backward pass
# Iter[187] Function fired after backward pass
# Iter[188] Function fired after backward pass
# Iter[189] Function fired after backward pass
# Iter[190] Function fired after backward pass
# Iter[191] Function fired after backward pass
# Iter[192] Function fired after backward pass
# Iter[193] Function fired after backward pass
# Iter[194] Function fired after backward pass
# Iter[195] Function fired after backward pass
# Iter[196] Function fired after backward pass
# Iter[197] Function fired after backward pass
# Iter[198] Function fired after backward pass
# Iter[199] Function fired after backward pass
# Iter[200] Function fired after backward pass
# Iter[201] Function fired after backward pass
# Iter[202] Function fired after backward pass
# Iter[203] Function fired after backward pass
# Iter[204] Function fired after backward pass
# Iter[205] Function fired after backward pass
# Iter[206] Function fired after backward pass
# Iter[207] Function fired after backward pass
# Iter[208] Function fired after backward pass
# Iter[209] Function fired after backward pass
# Iter[210] Function fired after backward pass
# Iter[211] Function fired after backward pass
# Iter[212] Function fired after backward pass
# Iter[213] Function fired after backward pass
# Iter[214] Function fired after backward pass
# Iter[215] Function fired after backward pass
# Iter[216] Function fired after backward pass
# Iter[217] Function fired after backward pass
# Iter[218] Function fired after backward pass
# Iter[219] Function fired after backward pass
# Iter[220] Function fired after backward pass
# Iter[221] Function fired after backward pass
# Iter[222] Function fired after backward pass
# Iter[223] Function fired after backward pass
# Iter[224] Function fired after backward pass
# Iter[225] Function fired after backward pass
# Iter[226] Function fired after backward pass
# Iter[227] Function fired after backward pass
# Iter[228] Function fired after backward pass
# Iter[229] Function fired after backward pass
# Iter[230] Function fired after backward pass
# Iter[231] Function fired after backward pass
# Iter[232] Function fired after backward pass
# Iter[233] Function fired after backward pass
# Iter[234] Function fired after backward pass
# Iter[235] Function fired after backward pass
# Iter[236] Function fired after backward pass
# Iter[237] Function fired after backward pass
# Iter[238] Function fired after backward pass
# Iter[239] Function fired after backward pass
# Iter[240] Function fired after backward pass
# Iter[241] Function fired after backward pass
# Iter[242] Function fired after backward pass
# Iter[243] Function fired after backward pass
# Iter[244] Function fired after backward pass
# Iter[245] Function fired after backward pass
# Iter[246] Function fired after backward pass
# Iter[247] Function fired after backward pass
# Iter[248] Function fired after backward pass
# Iter[249] Function fired after backward pass
# Iter[250] Function fired after backward pass
# Iter[251] Function fired after backward pass
# Iter[252] Function fired after backward pass
# Iter[253] Function fired after backward pass
# Iter[254] Function fired after backward pass
# Iter[255] Function fired after backward pass
# Iter[256] Function fired after backward pass
# Iter[257] Function fired after backward pass
# Iter[258] Function fired after backward pass
# Iter[259] Function fired after backward pass
# Iter[260] Function fired after backward pass
# Iter[261] Function fired after backward pass
# Iter[262] Function fired after backward pass
# Iter[263] Function fired after backward pass
# Iter[264] Function fired after backward pass
# Iter[265] Function fired after backward pass
# Iter[266] Function fired after backward pass
# Iter[267] Function fired after backward pass
# Iter[268] Function fired after backward pass
# Iter[269] Function fired after backward pass
# Iter[270] Function fired after backward pass
# Iter[271] Function fired after backward pass
# Iter[272] Function fired after backward pass
# Iter[273] Function fired after backward pass
# Iter[274] Function fired after backward pass
# Iter[275] Function fired after backward pass
# Iter[276] Function fired after backward pass
# Iter[277] Function fired after backward pass
# Iter[278] Function fired after backward pass
# Iter[279] Function fired after backward pass
# Iter[280] Function fired after backward pass
# Iter[281] Function fired after backward pass
# Iter[282] Function fired after backward pass
# Iter[283] Function fired after backward pass
# Iter[284] Function fired after backward pass
# Iter[285] Function fired after backward pass
# Iter[286] Function fired after backward pass
# Iter[287] Function fired after backward pass
# Iter[288] Function fired after backward pass
# Iter[289] Function fired after backward pass
# Iter[290] Function fired after backward pass
# Iter[291] Function fired after backward pass
# Iter[292] Function fired after backward pass
# Iter[293] Function fired after backward pass
# Iter[294] Function fired after backward pass
# Iter[295] Function fired after backward pass
# Iter[296] Function fired after backward pass
# Iter[297] Function fired after backward pass
# Iter[298] Function fired after backward pass
# Iter[299] Function fired after backward pass
# Iter[300] Function fired after backward pass
# Iter[301] Function fired after backward pass
# Iter[302] Function fired after backward pass
# Iter[303] Function fired after backward pass
# Iter[304] Function fired after backward pass
# Iter[305] Function fired after backward pass
# Iter[306] Function fired after backward pass
# Iter[307] Function fired after backward pass
# Iter[308] Function fired after backward pass
# Iter[309] Function fired after backward pass
# Iter[310] Function fired after backward pass
# Iter[311] Function fired after backward pass
# Iter[312] Function fired after backward pass
# Iter[313] Function fired after backward pass
# Iter[314] Function fired after backward pass
# Iter[315] Function fired after backward pass
# Iter[316] Function fired after backward pass
# Iter[317] Function fired after backward pass
# Iter[318] Function fired after backward pass
# Iter[319] Function fired after backward pass
# Iter[320] Function fired after backward pass
# Iter[321] Function fired after backward pass
# Iter[322] Function fired after backward pass
# Iter[323] Function fired after backward pass
# Iter[324] Function fired after backward pass
# Iter[325] Function fired after backward pass
# Iter[326] Function fired after backward pass
# Iter[327] Function fired after backward pass
# Iter[328] Function fired after backward pass
# Iter[329] Function fired after backward pass
# Iter[330] Function fired after backward pass
# Iter[331] Function fired after backward pass
# Iter[332] Function fired after backward pass
# Iter[333] Function fired after backward pass
# Iter[334] Function fired after backward pass
# Iter[335] Function fired after backward pass
# Iter[336] Function fired after backward pass
# Iter[337] Function fired after backward pass
# Iter[338] Function fired after backward pass
# Iter[339] Function fired after backward pass
# Iter[340] Function fired after backward pass
# Iter[341] Function fired after backward pass
# Iter[342] Function fired after backward pass
# Iter[343] Function fired after backward pass
# Iter[344] Function fired after backward pass
# Iter[345] Function fired after backward pass
# Iter[346] Function fired after backward pass
# Iter[347] Function fired after backward pass
# Iter[348] Function fired after backward pass
# Iter[349] Function fired after backward pass
# Iter[350] Function fired after backward pass
# Iter[351] Function fired after backward pass
# Iter[352] Function fired after backward pass
# Iter[353] Function fired after backward pass
# Iter[354] Function fired after backward pass
# Iter[355] Function fired after backward pass
# Iter[356] Function fired after backward pass
# Iter[357] Function fired after backward pass
# Iter[358] Function fired after backward pass
# Iter[359] Function fired after backward pass
# Iter[360] Function fired after backward pass
# Iter[361] Function fired after backward pass
# Iter[362] Function fired after backward pass
# Iter[363] Function fired after backward pass
# Iter[364] Function fired after backward pass
# Iter[365] Function fired after backward pass
# Iter[366] Function fired after backward pass
# Iter[367] Function fired after backward pass
# Iter[368] Function fired after backward pass
# Iter[369] Function fired after backward pass
# Iter[370] Function fired after backward pass
# Iter[371] Function fired after backward pass
# Iter[372] Function fired after backward pass
# Iter[373] Function fired after backward pass
# Iter[374] Function fired after backward pass
# Iter[375] Function fired after backward pass
# Iter[376] Function fired after backward pass
# Iter[377] Function fired after backward pass
# Iter[378] Function fired after backward pass
# Iter[379] Function fired after backward pass
# Iter[380] Function fired after backward pass
# Iter[381] Function fired after backward pass
# Iter[382] Function fired after backward pass
# Iter[383] Function fired after backward pass
# Iter[384] Function fired after backward pass
# Iter[385] Function fired after backward pass
# Iter[386] Function fired after backward pass
# Iter[387] Function fired after backward pass
# Iter[388] Function fired after backward pass
# Iter[389] Function fired after backward pass
# Iter[390] Function fired after backward pass
# Iter[391] Function fired after backward pass
# Iter[392] Function fired after backward pass
# Iter[393] Function fired after backward pass
# Iter[394] Function fired after backward pass
# Iter[395] Function fired after backward pass
# Iter[396] Function fired after backward pass
# Iter[397] Function fired after backward pass
# Iter[398] Function fired after backward pass
# Iter[399] Function fired after backward pass
# Iter[400] Function fired after backward pass
# Iter[401] Function fired after backward pass
# Iter[402] Function fired after backward pass
# Iter[403] Function fired after backward pass
# Iter[404] Function fired after backward pass
# Iter[405] Function fired after backward pass
# Iter[406] Function fired after backward pass
# Iter[407] Function fired after backward pass
# Iter[408] Function fired after backward pass
# Iter[409] Function fired after backward pass
# Iter[410] Function fired after backward pass
# Iter[411] Function fired after backward pass
# Iter[412] Function fired after backward pass
# Iter[413] Function fired after backward pass
# Iter[414] Function fired after backward pass
# Iter[415] Function fired after backward pass
# Iter[416] Function fired after backward pass
# Iter[417] Function fired after backward pass
# Iter[418] Function fired after backward pass
# Iter[419] Function fired after backward pass
# Iter[420] Function fired after backward pass
# Iter[421] Function fired after backward pass
# Iter[422] Function fired after backward pass
# Iter[423] Function fired after backward pass
# Iter[424] Function fired after backward pass
# Iter[425] Function fired after backward pass
# Iter[426] Function fired after backward pass
# Iter[427] Function fired after backward pass
# Iter[428] Function fired after backward pass
# Iter[429] Function fired after backward pass
# Iter[430] Function fired after backward pass
# Iter[431] Function fired after backward pass
# Iter[432] Function fired after backward pass
# Iter[433] Function fired after backward pass
# Iter[434] Function fired after backward pass
# Iter[435] Function fired after backward pass
# Iter[436] Function fired after backward pass
# Iter[437] Function fired after backward pass
# Iter[438] Function fired after backward pass
# Iter[439] Function fired after backward pass
# Iter[440] Function fired after backward pass
# Iter[441] Function fired after backward pass
# Iter[442] Function fired after backward pass
# Iter[443] Function fired after backward pass
# Iter[444] Function fired after backward pass
# Iter[445] Function fired after backward pass
# Iter[446] Function fired after backward pass
# Iter[447] Function fired after backward pass
# Iter[448] Function fired after backward pass
# Iter[449] Function fired after backward pass
# Iter[450] Function fired after backward pass
# Iter[451] Function fired after backward pass
# Iter[452] Function fired after backward pass
# Iter[453] Function fired after backward pass
# Iter[454] Function fired after backward pass
# Iter[455] Function fired after backward pass
# Iter[456] Function fired after backward pass
# Iter[457] Function fired after backward pass
# Iter[458] Function fired after backward pass
# Iter[459] Function fired after backward pass
# Iter[460] Function fired after backward pass
# Iter[461] Function fired after backward pass
# Iter[462] Function fired after backward pass
# Iter[463] Function fired after backward pass
# Iter[464] Function fired after backward pass
# Iter[465] Function fired after backward pass
# Iter[466] Function fired after backward pass
# Iter[467] Function fired after backward pass
# Iter[468] Function fired after backward pass
# Iter[469] Function fired after backward pass
# Iter[470] Function fired after backward pass
# Iter[471] Function fired after backward pass
# Iter[472] Function fired after backward pass
# Iter[473] Function fired after backward pass
# Iter[474] Function fired after backward pass
# Iter[475] Function fired after backward pass
# Iter[476] Function fired after backward pass
# Iter[477] Function fired after backward pass
# Iter[478] Function fired after backward pass
# Iter[479] Function fired after backward pass
# Iter[480] Function fired after backward pass
# Iter[481] Function fired after backward pass
# Iter[482] Function fired after backward pass
# Iter[483] Function fired after backward pass
# Iter[484] Function fired after backward pass
# Iter[485] Function fired after backward pass
# Iter[486] Function fired after backward pass
# Iter[487] Function fired after backward pass
# Iter[488] Function fired after backward pass
# Iter[489] Function fired after backward pass
# Iter[490] Function fired after backward pass
# Iter[491] Function fired after backward pass
# Iter[492] Function fired after backward pass
# Iter[493] Function fired after backward pass
# Iter[494] Function fired after backward pass
# Iter[495] Function fired after backward pass
# Iter[496] Function fired after backward pass
# Iter[497] Function fired after backward pass
# Iter[498] Function fired after backward pass
# Iter[499] Function fired after backward pass
# Iter[500] Function fired after backward pass
# Iter[501] Function fired after backward pass
# Iter[502] Function fired after backward pass
# Iter[503] Function fired after backward pass
# Iter[504] Function fired after backward pass
# Iter[505] Function fired after backward pass
# Iter[506] Function fired after backward pass
# Iter[507] Function fired after backward pass
# Iter[508] Function fired after backward pass
# Iter[509] Function fired after backward pass
# Iter[510] Function fired after backward pass
# Iter[511] Function fired after backward pass
# Iter[512] Function fired after backward pass
# Iter[513] Function fired after backward pass
# Iter[514] Function fired after backward pass
# Iter[515] Function fired after backward pass
# Iter[516] Function fired after backward pass
# Iter[517] Function fired after backward pass
# Iter[518] Function fired after backward pass
# Iter[519] Function fired after backward pass
# Iter[520] Function fired after backward pass
# Iter[521] Function fired after backward pass
# Iter[522] Function fired after backward pass
# Iter[523] Function fired after backward pass
# Iter[524] Function fired after backward pass
# Iter[525] Function fired after backward pass
# Iter[526] Function fired after backward pass
# Iter[527] Function fired after backward pass
# Iter[528] Function fired after backward pass
# Iter[529] Function fired after backward pass
# Iter[530] Function fired after backward pass
# Iter[531] Function fired after backward pass
# Iter[532] Function fired after backward pass
# Iter[533] Function fired after backward pass
# Iter[534] Function fired after backward pass
# Iter[535] Function fired after backward pass
# Iter[536] Function fired after backward pass
# Iter[537] Function fired after backward pass
# Iter[538] Function fired after backward pass
# Iter[539] Function fired after backward pass
# Iter[540] Function fired after backward pass
# Iter[541] Function fired after backward pass
# Iter[542] Function fired after backward pass
# Iter[543] Function fired after backward pass
# Iter[544] Function fired after backward pass
# Iter[545] Function fired after backward pass
# Iter[546] Function fired after backward pass
# Iter[547] Function fired after backward pass
# Iter[548] Function fired after backward pass
# Iter[549] Function fired after backward pass
# Iter[550] Function fired after backward pass
# Iter[551] Function fired after backward pass
# Iter[552] Function fired after backward pass
# Iter[553] Function fired after backward pass
# Iter[554] Function fired after backward pass
# Iter[555] Function fired after backward pass
# Iter[556] Function fired after backward pass
# Iter[557] Function fired after backward pass
# Iter[558] Function fired after backward pass
# Iter[559] Function fired after backward pass
# Iter[560] Function fired after backward pass
# Iter[561] Function fired after backward pass
# Iter[562] Function fired after backward pass
# Iter[563] Function fired after backward pass
# Iter[564] Function fired after backward pass
# Iter[565] Function fired after backward pass
# Iter[566] Function fired after backward pass
# Iter[567] Function fired after backward pass
# Iter[568] Function fired after backward pass
# Iter[569] Function fired after backward pass
# Iter[570] Function fired after backward pass
# Iter[571] Function fired after backward pass
# Iter[572] Function fired after backward pass
# Iter[573] Function fired after backward pass
# Iter[574] Function fired after backward pass
# Iter[575] Function fired after backward pass
# Iter[576] Function fired after backward pass
# Iter[577] Function fired after backward pass
# Iter[578] Function fired after backward pass
# Iter[579] Function fired after backward pass
# Iter[580] Function fired after backward pass
# Iter[581] Function fired after backward pass
# Iter[582] Function fired after backward pass
# Iter[583] Function fired after backward pass
# Iter[584] Function fired after backward pass
# Iter[585] Function fired after backward pass
# Iter[586] Function fired after backward pass
# Iter[587] Function fired after backward pass
# Iter[588] Function fired after backward pass
# Iter[589] Function fired after backward pass
# Iter[590] Function fired after backward pass
# Iter[591] Function fired after backward pass
# Iter[592] Function fired after backward pass
# Iter[593] Function fired after backward pass
# Iter[594] Function fired after backward pass
# Iter[595] Function fired after backward pass
# Iter[596] Function fired after backward pass
# Iter[597] Function fired after backward pass
# Iter[598] Function fired after backward pass
# Iter[599] Function fired after backward pass
# Iter[600] Function fired after backward pass
# Iter[601] Function fired after backward pass
# Iter[602] Function fired after backward pass
# Iter[603] Function fired after backward pass
# Iter[604] Function fired after backward pass
# Iter[605] Function fired after backward pass
# Iter[606] Function fired after backward pass
# Iter[607] Function fired after backward pass
# Iter[608] Function fired after backward pass
# Iter[609] Function fired after backward pass
# Iter[610] Function fired after backward pass
# Iter[611] Function fired after backward pass
# Iter[612] Function fired after backward pass
# Iter[613] Function fired after backward pass
# Iter[614] Function fired after backward pass
# Iter[615] Function fired after backward pass
# Iter[616] Function fired after backward pass
# Iter[617] Function fired after backward pass
# Iter[618] Function fired after backward pass
# Iter[619] Function fired after backward pass
# Iter[620] Function fired after backward pass
# Iter[621] Function fired after backward pass
# Iter[622] Function fired after backward pass
# Iter[623] Function fired after backward pass
# Iter[624] Function fired after backward pass
# Iter[625] Function fired after backward pass
# Iter[626] Function fired after backward pass
# Iter[627] Function fired after backward pass
# Iter[628] Function fired after backward pass
# Iter[629] Function fired after backward pass
# Iter[630] Function fired after backward pass
# Iter[631] Function fired after backward pass
# Iter[632] Function fired after backward pass
# Iter[633] Function fired after backward pass
# Iter[634] Function fired after backward pass
# Iter[635] Function fired after backward pass
# Iter[636] Function fired after backward pass
# Iter[637] Function fired after backward pass
# Iter[638] Function fired after backward pass
# Iter[639] Function fired after backward pass
# Iter[640] Function fired after backward pass
# Iter[641] Function fired after backward pass
# Iter[642] Function fired after backward pass
# Iter[643] Function fired after backward pass
# Iter[644] Function fired after backward pass
# Iter[645] Function fired after backward pass
# Iter[646] Function fired after backward pass
# Iter[647] Function fired after backward pass
# Iter[648] Function fired after backward pass
# Iter[649] Function fired after backward pass
# Iter[650] Function fired after backward pass
# Iter[651] Function fired after backward pass
# Iter[652] Function fired after backward pass
# Iter[653] Function fired after backward pass
# Iter[654] Function fired after backward pass
# Iter[655] Function fired after backward pass
# Iter[656] Function fired after backward pass
# Iter[657] Function fired after backward pass
# Iter[658] Function fired after backward pass
# Iter[659] Function fired after backward pass
# Iter[660] Function fired after backward pass
# Iter[661] Function fired after backward pass
# Iter[662] Function fired after backward pass
# Iter[663] Function fired after backward pass
# Iter[664] Function fired after backward pass
# Iter[665] Function fired after backward pass
# Iter[666] Function fired after backward pass
# Iter[667] Function fired after backward pass
# Iter[668] Function fired after backward pass
# Iter[669] Function fired after backward pass
# Iter[670] Function fired after backward pass
# Iter[671] Function fired after backward pass
# Iter[672] Function fired after backward pass
# Iter[673] Function fired after backward pass
# Iter[674] Function fired after backward pass
# Iter[675] Function fired after backward pass
# Iter[676] Function fired after backward pass
# Iter[677] Function fired after backward pass
# Iter[678] Function fired after backward pass
# Iter[679] Function fired after backward pass
# Iter[680] Function fired after backward pass
# Iter[681] Function fired after backward pass
# Iter[682] Function fired after backward pass
# Iter[683] Function fired after backward pass
# Iter[684] Function fired after backward pass
# Iter[685] Function fired after backward pass
# Iter[686] Function fired after backward pass
# Iter[687] Function fired after backward pass
# Iter[688] Function fired after backward pass
# Iter[689] Function fired after backward pass
# Iter[690] Function fired after backward pass
# Iter[691] Function fired after backward pass
# Iter[692] Function fired after backward pass
# Iter[693] Function fired after backward pass
# Iter[694] Function fired after backward pass
# Iter[695] Function fired after backward pass
# Iter[696] Function fired after backward pass
# Iter[697] Function fired after backward pass
# Iter[698] Function fired after backward pass
# Iter[699] Function fired after backward pass
# Iter[700] Function fired after backward pass
# Iter[701] Function fired after backward pass
# Iter[702] Function fired after backward pass
# Iter[703] Function fired after backward pass
# Iter[704] Function fired after backward pass
# Iter[705] Function fired after backward pass
# Iter[706] Function fired after backward pass
# Iter[707] Function fired after backward pass
# Iter[708] Function fired after backward pass
# Iter[709] Function fired after backward pass
# Iter[710] Function fired after backward pass
# Iter[711] Function fired after backward pass
# Iter[712] Function fired after backward pass
# Iter[713] Function fired after backward pass
# Iter[714] Function fired after backward pass
# Iter[715] Function fired after backward pass
# Iter[716] Function fired after backward pass
# Iter[717] Function fired after backward pass
# Iter[718] Function fired after backward pass
# Iter[719] Function fired after backward pass
# Iter[720] Function fired after backward pass
# Iter[721] Function fired after backward pass
# Iter[722] Function fired after backward pass
# Iter[723] Function fired after backward pass
# Iter[724] Function fired after backward pass
# Iter[725] Function fired after backward pass
# Iter[726] Function fired after backward pass
# Iter[727] Function fired after backward pass
# Iter[728] Function fired after backward pass
# Iter[729] Function fired after backward pass
# Iter[730] Function fired after backward pass
# Iter[731] Function fired after backward pass
# Iter[732] Function fired after backward pass
# Iter[733] Function fired after backward pass
# Iter[734] Function fired after backward pass
# Iter[735] Function fired after backward pass
# Iter[736] Function fired after backward pass
# Iter[737] Function fired after backward pass
# Iter[738] Function fired after backward pass
# Iter[739] Function fired after backward pass
# Iter[740] Function fired after backward pass
# Iter[741] Function fired after backward pass
# Iter[742] Function fired after backward pass
# Iter[743] Function fired after backward pass
# Iter[744] Function fired after backward pass
# Iter[745] Function fired after backward pass
# Iter[746] Function fired after backward pass
# Iter[747] Function fired after backward pass
# Iter[748] Function fired after backward pass
# Iter[749] Function fired after backward pass
# Iter[750] Function fired after backward pass
# Iter[751] Function fired after backward pass
# Iter[752] Function fired after backward pass
# Iter[753] Function fired after backward pass
# Iter[754] Function fired after backward pass
# Iter[755] Function fired after backward pass
# Iter[756] Function fired after backward pass
# Iter[757] Function fired after backward pass
# Iter[758] Function fired after backward pass
# Iter[759] Function fired after backward pass
# Iter[760] Function fired after backward pass
# Iter[761] Function fired after backward pass
# Iter[762] Function fired after backward pass
# Iter[763] Function fired after backward pass
# Iter[764] Function fired after backward pass
# Iter[765] Function fired after backward pass
# Iter[766] Function fired after backward pass
# Iter[767] Function fired after backward pass
# Iter[768] Function fired after backward pass
# Iter[769] Function fired after backward pass
# Iter[770] Function fired after backward pass
# Iter[771] Function fired after backward pass
# Iter[772] Function fired after backward pass
# Iter[773] Function fired after backward pass
# Iter[774] Function fired after backward pass
# Iter[775] Function fired after backward pass
# Iter[776] Function fired after backward pass
# Iter[777] Function fired after backward pass
# Iter[778] Function fired after backward pass
# Iter[779] Function fired after backward pass
# Iter[780] Function fired after backward pass
# Iter[781] Function fired after backward pass
# Iter[782] Function fired after backward pass
# Iter[783] Function fired after backward pass
# Iter[784] Function fired after backward pass
# Iter[785] Function fired after backward pass
# Iter[786] Function fired after backward pass
# Iter[787] Function fired after backward pass
# Iter[788] Function fired after backward pass
# Iter[789] Function fired after backward pass
# Iter[790] Function fired after backward pass
# Iter[791] Function fired after backward pass
# Iter[792] Function fired after backward pass
# Iter[793] Function fired after backward pass
# Iter[794] Function fired after backward pass
# Iter[795] Function fired after backward pass
# Iter[796] Function fired after backward pass
# Iter[797] Function fired after backward pass
# Iter[798] Function fired after backward pass
# Iter[799] Function fired after backward pass
# Iter[800] Function fired after backward pass
# Iter[801] Function fired after backward pass
# Iter[802] Function fired after backward pass
# Iter[803] Function fired after backward pass
# Iter[804] Function fired after backward pass
# Iter[805] Function fired after backward pass
# Iter[806] Function fired after backward pass
# Iter[807] Function fired after backward pass
# Iter[808] Function fired after backward pass
# Iter[809] Function fired after backward pass
# Iter[810] Function fired after backward pass
# Iter[811] Function fired after backward pass
# Iter[812] Function fired after backward pass
# Iter[813] Function fired after backward pass
# Iter[814] Function fired after backward pass
# Iter[815] Function fired after backward pass
# Iter[816] Function fired after backward pass
# Iter[817] Function fired after backward pass
# Iter[818] Function fired after backward pass
# Iter[819] Function fired after backward pass
# Iter[820] Function fired after backward pass
# Iter[821] Function fired after backward pass
# Iter[822] Function fired after backward pass
# Iter[823] Function fired after backward pass
# Iter[824] Function fired after backward pass
# Iter[825] Function fired after backward pass
# Iter[826] Function fired after backward pass
# Iter[827] Function fired after backward pass
# Iter[828] Function fired after backward pass
# Iter[829] Function fired after backward pass
# Iter[830] Function fired after backward pass
# Iter[831] Function fired after backward pass
# Iter[832] Function fired after backward pass
# Iter[833] Function fired after backward pass
# Iter[834] Function fired after backward pass
# Iter[835] Function fired after backward pass
# Iter[836] Function fired after backward pass
# Iter[837] Function fired after backward pass
# Iter[838] Function fired after backward pass
# Iter[839] Function fired after backward pass
# Iter[840] Function fired after backward pass
# Iter[841] Function fired after backward pass
# Iter[842] Function fired after backward pass
# Iter[843] Function fired after backward pass
# Iter[844] Function fired after backward pass
# Iter[845] Function fired after backward pass
# Iter[846] Function fired after backward pass
# Iter[847] Function fired after backward pass
# Iter[848] Function fired after backward pass
# Iter[849] Function fired after backward pass
# Iter[850] Function fired after backward pass
# Iter[851] Function fired after backward pass
# Iter[852] Function fired after backward pass
# Iter[853] Function fired after backward pass
# Iter[854] Function fired after backward pass
# Iter[855] Function fired after backward pass
# Iter[856] Function fired after backward pass
# Iter[857] Function fired after backward pass
# Iter[858] Function fired after backward pass
# Iter[859] Function fired after backward pass
# Iter[860] Function fired after backward pass
# Iter[861] Function fired after backward pass
# Iter[862] Function fired after backward pass
# Iter[863] Function fired after backward pass
# Iter[864] Function fired after backward pass
# Iter[865] Function fired after backward pass
# Iter[866] Function fired after backward pass
# Iter[867] Function fired after backward pass
# Iter[868] Function fired after backward pass
# Iter[869] Function fired after backward pass
# Iter[870] Function fired after backward pass
# Iter[871] Function fired after backward pass
# Iter[872] Function fired after backward pass
# Iter[873] Function fired after backward pass
# Iter[874] Function fired after backward pass
# Iter[875] Function fired after backward pass
# Iter[876] Function fired after backward pass
# Iter[877] Function fired after backward pass
# Iter[878] Function fired after backward pass
# Iter[879] Function fired after backward pass
# Iter[880] Function fired after backward pass
# Iter[881] Function fired after backward pass
# Iter[882] Function fired after backward pass
# Iter[883] Function fired after backward pass
# Iter[884] Function fired after backward pass
# Iter[885] Function fired after backward pass
# Iter[886] Function fired after backward pass
# Iter[887] Function fired after backward pass
# Iter[888] Function fired after backward pass
# Iter[889] Function fired after backward pass
# Iter[890] Function fired after backward pass
# Iter[891] Function fired after backward pass
# Iter[892] Function fired after backward pass
# Iter[893] Function fired after backward pass
# Iter[894] Function fired after backward pass
# Iter[895] Function fired after backward pass
# Iter[896] Function fired after backward pass
# Iter[897] Function fired after backward pass
# Iter[898] Function fired after backward pass
# Iter[899] Function fired after backward pass
# Iter[900] Function fired after backward pass
# Iter[901] Function fired after backward pass
# Iter[902] Function fired after backward pass
# Iter[903] Function fired after backward pass
# Iter[904] Function fired after backward pass
# Iter[905] Function fired after backward pass
# Iter[906] Function fired after backward pass
# Iter[907] Function fired after backward pass
# Iter[908] Function fired after backward pass
# Iter[909] Function fired after backward pass
# Iter[910] Function fired after backward pass
# Iter[911] Function fired after backward pass
# Iter[912] Function fired after backward pass
# Iter[913] Function fired after backward pass
# Iter[914] Function fired after backward pass
# Iter[915] Function fired after backward pass
# Iter[916] Function fired after backward pass
# Iter[917] Function fired after backward pass
# Iter[918] Function fired after backward pass
# Iter[919] Function fired after backward pass
# Iter[920] Function fired after backward pass
# Iter[921] Function fired after backward pass
# Iter[922] Function fired after backward pass
# Iter[923] Function fired after backward pass
# Iter[924] Function fired after backward pass
# Iter[925] Function fired after backward pass
# Iter[926] Function fired after backward pass
# Iter[927] Function fired after backward pass
# Iter[928] Function fired after backward pass
# Iter[929] Function fired after backward pass
# Iter[930] Function fired after backward pass
# Iter[931] Function fired after backward pass
# Iter[932] Function fired after backward pass
# Iter[933] Function fired after backward pass
# Iter[934] Function fired after backward pass
# Iter[935] Function fired after backward pass
# Iter[936] Function fired after backward pass
# Iter[937] Function fired after backward pass
# Iter[938] Function fired after backward pass
# Iter[939] Function fired after backward pass
# Iter[940] Function fired after backward pass
# Iter[941] Function fired after backward pass
# Iter[942] Function fired after backward pass
# Iter[943] Function fired after backward pass
# Iter[944] Function fired after backward pass
# Iter[945] Function fired after backward pass
# Iter[946] Function fired after backward pass
# Iter[947] Function fired after backward pass
# Iter[948] Function fired after backward pass
# Iter[949] Function fired after backward pass
# Iter[950] Function fired after backward pass
# Iter[951] Function fired after backward pass
# Iter[952] Function fired after backward pass
# Iter[953] Function fired after backward pass
# Iter[954] Function fired after backward pass
# Iter[955] Function fired after backward pass
# Iter[956] Function fired after backward pass
# Iter[957] Function fired after backward pass
# Iter[958] Function fired after backward pass
# Iter[959] Function fired after backward pass
# Iter[960] Function fired after backward pass
# Iter[961] Function fired after backward pass
# Iter[962] Function fired after backward pass
# Iter[963] Function fired after backward pass
# Iter[964] Function fired after backward pass
# Iter[965] Function fired after backward pass
# Iter[966] Function fired after backward pass
# Iter[967] Function fired after backward pass
# Iter[968] Function fired after backward pass
# Iter[969] Function fired after backward pass
# Iter[970] Function fired after backward pass
# Iter[971] Function fired after backward pass
# Iter[972] Function fired after backward pass
# Iter[973] Function fired after backward pass
# Iter[974] Function fired after backward pass
# Iter[975] Function fired after backward pass
# Iter[976] Function fired after backward pass
# Iter[977] Function fired after backward pass
# Iter[978] Function fired after backward pass
# Iter[979] Function fired after backward pass
# Iter[980] Function fired after backward pass
# Iter[981] Function fired after backward pass
# Iter[982] Function fired after backward pass
# Iter[983] Function fired after backward pass
# Iter[984] Function fired after backward pass
# Iter[985] Function fired after backward pass
# Iter[986] Function fired after backward pass
# Iter[987] Function fired after backward pass
# Iter[988] Function fired after backward pass
# Iter[989] Function fired after backward pass
# Iter[990] Function fired after backward pass
# Iter[991] Function fired after backward pass
# Iter[992] Function fired after backward pass
# Iter[993] Function fired after backward pass
# Iter[994] Function fired after backward pass
# Iter[995] Function fired after backward pass
# Iter[996] Function fired after backward pass
# Iter[997] Function fired after backward pass
# Iter[998] Function fired after backward pass
# Iter[999] Function fired after backward pass
# Iter[1000] Function fired after backward pass
# Iter[1001] Function fired after backward pass
# Iter[1002] Function fired after backward pass
# Iter[1003] Function fired after backward pass
# Iter[1004] Function fired after backward pass
# Iter[1005] Function fired after backward pass
# Iter[1006] Function fired after backward pass
# Iter[1007] Function fired after backward pass
# Iter[1008] Function fired after backward pass
# Iter[1009] Function fired after backward pass
# Iter[1010] Function fired after backward pass
# Iter[1011] Function fired after backward pass
# Iter[1012] Function fired after backward pass
# Iter[1013] Function fired after backward pass
# Iter[1014] Function fired after backward pass
# Iter[1015] Function fired after backward pass
# Iter[1016] Function fired after backward pass
# Iter[1017] Function fired after backward pass
# Iter[1018] Function fired after backward pass
# Iter[1019] Function fired after backward pass
# Iter[1020] Function fired after backward pass
# Iter[1021] Function fired after backward pass
# Iter[1022] Function fired after backward pass
# Iter[1023] Function fired after backward pass
# Iter[1024] Function fired after backward pass
# Iter[1025] Function fired after backward pass
# Iter[1026] Function fired after backward pass
# Iter[1027] Function fired after backward pass
# Iter[1028] Function fired after backward pass
# Iter[1029] Function fired after backward pass
# Iter[1030] Function fired after backward pass
# Iter[1031] Function fired after backward pass
# Iter[1032] Function fired after backward pass
# Iter[1033] Function fired after backward pass
# Iter[1034] Function fired after backward pass
# Iter[1035] Function fired after backward pass
# Iter[1036] Function fired after backward pass
# Iter[1037] Function fired after backward pass
# Iter[1038] Function fired after backward pass
# Iter[1039] Function fired after backward pass
# Iter[1040] Function fired after backward pass
# Iter[1041] Function fired after backward pass
# Iter[1042] Function fired after backward pass
# Iter[1043] Function fired after backward pass
# Iter[1044] Function fired after backward pass
# Iter[1045] Function fired after backward pass
# Iter[1046] Function fired after backward pass
# Iter[1047] Function fired after backward pass
# Iter[1048] Function fired after backward pass
# Iter[1049] Function fired after backward pass
# Iter[1050] Function fired after backward pass
# Iter[1051] Function fired after backward pass
# Iter[1052] Function fired after backward pass
# Iter[1053] Function fired after backward pass
# Iter[1054] Function fired after backward pass
# Iter[1055] Function fired after backward pass
# Iter[1056] Function fired after backward pass
# Iter[1057] Function fired after backward pass
# Iter[1058] Function fired after backward pass
# Iter[1059] Function fired after backward pass
# Iter[1060] Function fired after backward pass
# Iter[1061] Function fired after backward pass
# Iter[1062] Function fired after backward pass
# Iter[1063] Function fired after backward pass
# Iter[1064] Function fired after backward pass
# Iter[1065] Function fired after backward pass
# Iter[1066] Function fired after backward pass
# Iter[1067] Function fired after backward pass
# Iter[1068] Function fired after backward pass
# Iter[1069] Function fired after backward pass
# Iter[1070] Function fired after backward pass
# Iter[1071] Function fired after backward pass
# Iter[1072] Function fired after backward pass
# Iter[1073] Function fired after backward pass
# Iter[1074] Function fired after backward pass
# Iter[1075] Function fired after backward pass
# Iter[1076] Function fired after backward pass
# Iter[1077] Function fired after backward pass
# Iter[1078] Function fired after backward pass
# Iter[1079] Function fired after backward pass
# Iter[1080] Function fired after backward pass
# Iter[1081] Function fired after backward pass
# Iter[1082] Function fired after backward pass
# Iter[1083] Function fired after backward pass
# Iter[1084] Function fired after backward pass
# Iter[1085] Function fired after backward pass
# Iter[1086] Function fired after backward pass
# Iter[1087] Function fired after backward pass
# Iter[1088] Function fired after backward pass
# Iter[1089] Function fired after backward pass
# Iter[1090] Function fired after backward pass
# Iter[1091] Function fired after backward pass
# Iter[1092] Function fired after backward pass
# Iter[1093] Function fired after backward pass
# Iter[1094] Function fired after backward pass
# Iter[1095] Function fired after backward pass
# Iter[1096] Function fired after backward pass
# Iter[1097] Function fired after backward pass
# Iter[1098] Function fired after backward pass
# Iter[1099] Function fired after backward pass
# Iter[1100] Function fired after backward pass
# Iter[1101] Function fired after backward pass
# Iter[1102] Function fired after backward pass
# Iter[1103] Function fired after backward pass
# Iter[1104] Function fired after backward pass
# Iter[1105] Function fired after backward pass
# Iter[1106] Function fired after backward pass
# Iter[1107] Function fired after backward pass
# Iter[1108] Function fired after backward pass
# Iter[1109] Function fired after backward pass
# Iter[1110] Function fired after backward pass
# Iter[1111] Function fired after backward pass
# Iter[1112] Function fired after backward pass
# Iter[1113] Function fired after backward pass
# Iter[1114] Function fired after backward pass
# Iter[1115] Function fired after backward pass
# Iter[1116] Function fired after backward pass
# Iter[1117] Function fired after backward pass
# Iter[1118] Function fired after backward pass
# Iter[1119] Function fired after backward pass
# Iter[1120] Function fired after backward pass
# Iter[1121] Function fired after backward pass
# Iter[1122] Function fired after backward pass
# Iter[1123] Function fired after backward pass
# Iter[1124] Function fired after backward pass
# Iter[1125] Function fired after backward pass
# Iter[1126] Function fired after backward pass
# Iter[1127] Function fired after backward pass
# Iter[1128] Function fired after backward pass
# Iter[1129] Function fired after backward pass
# Iter[1130] Function fired after backward pass
# Iter[1131] Function fired after backward pass
# Iter[1132] Function fired after backward pass
# Iter[1133] Function fired after backward pass
# Iter[1134] Function fired after backward pass
# Iter[1135] Function fired after backward pass
# Iter[1136] Function fired after backward pass
# Iter[1137] Function fired after backward pass
# Iter[1138] Function fired after backward pass
# Iter[1139] Function fired after backward pass
# Iter[1140] Function fired after backward pass
# Iter[1141] Function fired after backward pass
# Iter[1142] Function fired after backward pass
# Iter[1143] Function fired after backward pass
# Iter[1144] Function fired after backward pass
# Iter[1145] Function fired after backward pass
# Iter[1146] Function fired after backward pass
# Iter[1147] Function fired after backward pass
# Iter[1148] Function fired after backward pass
# Iter[1149] Function fired after backward pass
# Iter[1150] Function fired after backward pass
# Iter[1151] Function fired after backward pass
# Iter[1152] Function fired after backward pass
# Iter[1153] Function fired after backward pass
# Iter[1154] Function fired after backward pass
# Iter[1155] Function fired after backward pass
# Iter[1156] Function fired after backward pass
# Iter[1157] Function fired after backward pass
# Iter[1158] Function fired after backward pass
# Iter[1159] Function fired after backward pass
# Iter[1160] Function fired after backward pass
# Iter[1161] Function fired after backward pass
# Iter[1162] Function fired after backward pass
# Iter[1163] Function fired after backward pass
# Iter[1164] Function fired after backward pass
# Iter[1165] Function fired after backward pass
# Iter[1166] Function fired after backward pass
# Iter[1167] Function fired after backward pass
# Iter[1168] Function fired after backward pass
# Iter[1169] Function fired after backward pass
# Iter[1170] Function fired after backward pass
# Iter[1171] Function fired after backward pass
# Iter[1172] Function fired after backward pass
# Iter[1173] Function fired after backward pass
# Iter[1174] Function fired after backward pass
# Iter[1175] Function fired after backward pass
# Iter[1176] Function fired after backward pass
# Iter[1177] Function fired after backward pass
# Iter[1178] Function fired after backward pass
# Iter[1179] Function fired after backward pass
# Iter[1180] Function fired after backward pass
# Iter[1181] Function fired after backward pass
# Iter[1182] Function fired after backward pass
# Iter[1183] Function fired after backward pass
# Iter[1184] Function fired after backward pass
# Iter[1185] Function fired after backward pass
# Iter[1186] Function fired after backward pass
# Iter[1187] Function fired after backward pass
# Iter[1188] Function fired after backward pass
# Iter[1189] Function fired after backward pass
# Iter[1190] Function fired after backward pass
# Iter[1191] Function fired after backward pass
# Iter[1192] Function fired after backward pass
# Iter[1193] Function fired after backward pass
# Iter[1194] Function fired after backward pass
# Iter[1195] Function fired after backward pass
# Iter[1196] Function fired after backward pass
# Iter[1197] Function fired after backward pass
# Iter[1198] Function fired after backward pass
# Iter[1199] Function fired after backward pass
# Iter[1200] Function fired after backward pass
# Iter[1201] Function fired after backward pass
# Iter[1202] Function fired after backward pass
# Iter[1203] Function fired after backward pass
# Iter[1204] Function fired after backward pass
# Iter[1205] Function fired after backward pass
# Iter[1206] Function fired after backward pass
# Iter[1207] Function fired after backward pass
# Iter[1208] Function fired after backward pass
# Iter[1209] Function fired after backward pass
# Iter[1210] Function fired after backward pass
# Iter[1211] Function fired after backward pass
# Iter[1212] Function fired after backward pass
# Iter[1213] Function fired after backward pass
# Iter[1214] Function fired after backward pass
# Iter[1215] Function fired after backward pass
# Iter[1216] Function fired after backward pass
# Iter[1217] Function fired after backward pass
# Iter[1218] Function fired after backward pass
# Iter[1219] Function fired after backward pass
# Iter[1220] Function fired after backward pass
# Iter[1221] Function fired after backward pass
# Iter[1222] Function fired after backward pass
# Iter[1223] Function fired after backward pass
# Iter[1224] Function fired after backward pass
# Iter[1225] Function fired after backward pass
# Iter[1226] Function fired after backward pass
# Iter[1227] Function fired after backward pass
# Iter[1228] Function fired after backward pass
# Iter[1229] Function fired after backward pass
# Iter[1230] Function fired after backward pass
# Iter[1231] Function fired after backward pass
# Iter[1232] Function fired after backward pass
# Iter[1233] Function fired after backward pass
# Iter[1234] Function fired after backward pass
# Iter[1235] Function fired after backward pass
# Iter[1236] Function fired after backward pass
# Iter[1237] Function fired after backward pass
# Iter[1238] Function fired after backward pass
# Iter[1239] Function fired after backward pass
# Iter[1240] Function fired after backward pass
# Iter[1241] Function fired after backward pass
# Iter[1242] Function fired after backward pass
# Iter[1243] Function fired after backward pass
# Iter[1244] Function fired after backward pass
# Iter[1245] Function fired after backward pass
# Iter[1246] Function fired after backward pass
# Iter[1247] Function fired after backward pass
# Iter[1248] Function fired after backward pass
# Iter[1249] Function fired after backward pass
# Iter[1250] Function fired after backward pass
# Iter[1251] Function fired after backward pass
# Iter[1252] Function fired after backward pass
# Iter[1253] Function fired after backward pass
# Iter[1254] Function fired after backward pass
# Iter[1255] Function fired after backward pass
# Iter[1256] Function fired after backward pass
# Iter[1257] Function fired after backward pass
# Iter[1258] Function fired after backward pass
# Iter[1259] Function fired after backward pass
# Iter[1260] Function fired after backward pass
# Iter[1261] Function fired after backward pass
# Iter[1262] Function fired after backward pass
# Iter[1263] Function fired after backward pass
# Iter[1264] Function fired after backward pass
# Iter[1265] Function fired after backward pass
# Iter[1266] Function fired after backward pass
# Iter[1267] Function fired after backward pass
# Iter[1268] Function fired after backward pass
# Iter[1269] Function fired after backward pass
# Iter[1270] Function fired after backward pass
# Iter[1271] Function fired after backward pass
# Iter[1272] Function fired after backward pass
# Iter[1273] Function fired after backward pass
# Iter[1274] Function fired after backward pass
# Iter[1275] Function fired after backward pass
# Iter[1276] Function fired after backward pass
# Iter[1277] Function fired after backward pass
# Iter[1278] Function fired after backward pass
# Iter[1279] Function fired after backward pass
# Iter[1280] Function fired after backward pass
# Iter[1281] Function fired after backward pass
# Iter[1282] Function fired after backward pass
# Iter[1283] Function fired after backward pass
# Iter[1284] Function fired after backward pass
# Iter[1285] Function fired after backward pass
# Iter[1286] Function fired after backward pass
# Iter[1287] Function fired after backward pass
# Iter[1288] Function fired after backward pass
# Iter[1289] Function fired after backward pass
# Iter[1290] Function fired after backward pass
# Iter[1291] Function fired after backward pass
# Iter[1292] Function fired after backward pass
# Iter[1293] Function fired after backward pass
# Iter[1294] Function fired after backward pass
# Iter[1295] Function fired after backward pass
# Iter[1296] Function fired after backward pass
# Iter[1297] Function fired after backward pass
# Iter[1298] Function fired after backward pass
# Iter[1299] Function fired after backward pass
# Iter[1300] Function fired after backward pass
# Iter[1301] Function fired after backward pass
# Iter[1302] Function fired after backward pass
# Iter[1303] Function fired after backward pass
# Iter[1304] Function fired after backward pass
# Iter[1305] Function fired after backward pass
# Iter[1306] Function fired after backward pass
# Iter[1307] Function fired after backward pass
# Iter[1308] Function fired after backward pass
# Iter[1309] Function fired after backward pass
# Iter[1310] Function fired after backward pass
# Iter[1311] Function fired after backward pass
# Iter[1312] Function fired after backward pass
# Iter[1313] Function fired after backward pass
# Iter[1314] Function fired after backward pass
# Iter[1315] Function fired after backward pass
# Iter[1316] Function fired after backward pass
# Iter[1317] Function fired after backward pass
# Iter[1318] Function fired after backward pass
# Iter[1319] Function fired after backward pass
# Iter[1320] Function fired after backward pass
# Iter[1321] Function fired after backward pass
# Iter[1322] Function fired after backward pass
# Iter[1323] Function fired after backward pass
# Iter[1324] Function fired after backward pass
# Iter[1325] Function fired after backward pass
# Iter[1326] Function fired after backward pass
# Iter[1327] Function fired after backward pass
# Iter[1328] Function fired after backward pass
# Iter[1329] Function fired after backward pass
# Iter[1330] Function fired after backward pass
# Iter[1331] Function fired after backward pass
# Iter[1332] Function fired after backward pass
# Iter[1333] Function fired after backward pass
# Iter[1334] Function fired after backward pass
# Iter[1335] Function fired after backward pass
# Iter[1336] Function fired after backward pass
# Iter[1337] Function fired after backward pass
# Iter[1338] Function fired after backward pass
# Iter[1339] Function fired after backward pass
# Iter[1340] Function fired after backward pass
# Iter[1341] Function fired after backward pass
# Iter[1342] Function fired after backward pass
# Iter[1343] Function fired after backward pass
# Iter[1344] Function fired after backward pass
# Iter[1345] Function fired after backward pass
# Iter[1346] Function fired after backward pass
# Iter[1347] Function fired after backward pass
# Iter[1348] Function fired after backward pass
# Iter[1349] Function fired after backward pass
# Iter[1350] Function fired after backward pass
# Iter[1351] Function fired after backward pass
# Iter[1352] Function fired after backward pass
# Iter[1353] Function fired after backward pass
# Iter[1354] Function fired after backward pass
# Iter[1355] Function fired after backward pass
# Iter[1356] Function fired after backward pass
# Iter[1357] Function fired after backward pass
# Iter[1358] Function fired after backward pass
# Iter[1359] Function fired after backward pass
# Iter[1360] Function fired after backward pass
# Iter[1361] Function fired after backward pass
# Iter[1362] Function fired after backward pass
# Iter[1363] Function fired after backward pass
# Iter[1364] Function fired after backward pass
# Iter[1365] Function fired after backward pass
# Iter[1366] Function fired after backward pass
# Iter[1367] Function fired after backward pass
# Iter[1368] Function fired after backward pass
# Iter[1369] Function fired after backward pass
# Iter[1370] Function fired after backward pass
# Iter[1371] Function fired after backward pass
# Iter[1372] Function fired after backward pass
# Iter[1373] Function fired after backward pass
# Iter[1374] Function fired after backward pass
# Iter[1375] Function fired after backward pass
# Iter[1376] Function fired after backward pass
# Iter[1377] Function fired after backward pass
# Iter[1378] Function fired after backward pass
# Iter[1379] Function fired after backward pass
# Iter[1380] Function fired after backward pass
# Iter[1381] Function fired after backward pass
# Iter[1382] Function fired after backward pass
# Iter[1383] Function fired after backward pass
# Iter[1384] Function fired after backward pass
# Iter[1385] Function fired after backward pass
# Iter[1386] Function fired after backward pass
# Iter[1387] Function fired after backward pass
# Iter[1388] Function fired after backward pass
# Iter[1389] Function fired after backward pass
# Iter[1390] Function fired after backward pass
# Iter[1391] Function fired after backward pass
# Iter[1392] Function fired after backward pass
# Iter[1393] Function fired after backward pass
# Iter[1394] Function fired after backward pass
# Iter[1395] Function fired after backward pass
# Iter[1396] Function fired after backward pass
# Iter[1397] Function fired after backward pass
# Iter[1398] Function fired after backward pass
# Iter[1399] Function fired after backward pass
# Iter[1400] Function fired after backward pass
# Iter[1401] Function fired after backward pass
# Iter[1402] Function fired after backward pass
# Iter[1403] Function fired after backward pass
# Iter[1404] Function fired after backward pass
# Iter[1405] Function fired after backward pass
# Iter[1406] Function fired after backward pass
# Iter[1407] Function fired after backward pass
# State:
# 	iteration: 1407
# 	epoch: 3
# 	epoch_length: 469
# 	max_epochs: 3
# 	output: 0.0011817800113931298
# 	batch: <class 'list'>
# 	metrics: <class 'dict'>
# 	dataloader: <class 'torch.utils.data.dataloader.DataLoader'>
# 	seed: <class 'NoneType'>
# 	times: <class 'dict'>
